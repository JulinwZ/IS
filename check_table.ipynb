# %%
import pickle
import pprint

filename = "table.pkl"

with open(filename, "rb") as file:
    data = pickle.load(file)

pprint.pprint(data)
# Out:
# {1: {'accept': False,
#      'error': True,
#      'guid_symbols': ['{',
#                       'if',
#                       'while',
#                       'return',
#                       'id',
#                       'int',
#                       'void',
#                       'bool',
#                       'NUM',
#                       'true',
#                       'false',
#                       '('],
#      'next_state': 71,
#      'return': False,
#      'stack': False},
#  2: {'accept': False,
#      'error': True,
#      'guid_symbols': ['int', 'void', 'bool'],
#      'next_state': 73,
#      'return': False,
#      'stack': False},
#  3: {'accept': False,
#      'error': False,
#      'guid_symbols': ['int'],
#      'next_state': 76,
#      'return': False,
#      'stack': False},
#  4: {'accept': False,
#      'error': False,
#      'guid_symbols': ['void'],
#      'next_state': 77,
#      'return': False,
#      'stack': False},
#  5: {'accept': False,
# ...
